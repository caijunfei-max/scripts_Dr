# %% [markdown]
# # 背景概述
#
# $\quad$1865年, 俄国化学家[门捷列夫(Mendeleev)](https://en.wikipedia.org/wiki/Dmitri_Mendeleev)根据相对原子质量的增长关系所呈现的周期性, 发表了最早版本的[元素周期表(periodic table)](https://en.wikipedia.org/wiki/Periodic_table). 在本次上机作业中, 我们将根据若干元素的原子参数数据, 尝试挖掘这些化学元素中的内禀规律, 并作一个简单的聚类分析.
# - 参考文献: [J. Chem. Educ. 2020, 97, 6, 1666–1676](https://pubs.acs.org/doi/10.1021/acs.jchemed.9b00924).
#
# $\quad$由于t-SNE算法的版本更新问题, 可能会输出一些警告(warning). 出于简化, 我们在本次作业中忽略这些警告. 请运行下面的代码块.

# %%
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # 数据读取与清洗
#
# $\quad$请运行下面的代码块, 读入`chem_elements.csv`数据集(已丢弃所有含缺失值的元素).

# %%
import pandas as pd
raw_data = pd.read_csv("/bohr/MLInChem-rc9x/v2/chem_elements.csv", sep=";").dropna()
raw_data
# Out:
#    Symbol        Name  AtomicMass ElectronConfiguration  Electronegativity  \
# 0       H    Hydrogen       1.008                   1s1               2.20
# 1      Li     Lithium       7.000               [He]2s1               0.98
# 3       B       Boron      10.810            [He]2s22p1               2.04
# 4       C      Carbon      12.011            [He]2s22p2               2.55
# 6       O      Oxygen      15.999            [He]2s22p4               3.44
# 7       F    Fluorine      18.998            [He]2s22p5               3.98
# 8      Na      Sodium      22.989               [Ne]3s1               0.93
# 10     Al    Aluminum      26.981            [Ne]3s23p1               1.61
# 11     Si     Silicon      28.085            [Ne]3s23p2               1.90
# 12      P  Phosphorus      30.973            [Ne]3s23p3               2.19
# 13      S      Sulfur      32.070            [Ne]3s23p4               2.58
# 14     Cl    Chlorine      35.450            [Ne]3s23p5               3.16
# 15      K   Potassium      39.098               [Ar]4s1               0.82
# 17     Sc    Scandium      44.955            [Ar]4s23d1               1.36
# 18     Ti    Titanium      47.870            [Ar]4s23d2               1.54
# 19      V    Vanadium      50.941            [Ar]4s23d3               1.63
# 20     Cr    Chromium      51.996            [Ar]3d54s1               1.66
# 22     Fe        Iron      55.840            [Ar]4s23d6               1.83
# 23     Co      Cobalt      58.933            [Ar]4s23d7               1.88
# 24     Ni      Nickel      58.693            [Ar]4s23d8               1.91
# 25     Cu      Copper      63.550           [Ar]4s13d10               1.90
# 27     Ga     Gallium      69.720        [Ar]4s23d104p1               1.81
# 28     Ge   Germanium      72.630        [Ar]4s23d104p2               2.01
# 29     As     Arsenic      74.921        [Ar]4s23d104p3               2.18
# 30     Se    Selenium      78.970        [Ar]4s23d104p4               2.55
# 31     Br     Bromine      79.900        [Ar]4s23d104p5               2.96
# 32     Rb    Rubidium      85.468               [Kr]5s1               0.82
# 34      Y     Yttrium      88.905            [Kr]5s24d1               1.22
# 35     Zr   Zirconium      91.220            [Kr]5s24d2               1.33
# 36     Nb     Niobium      92.906            [Kr]5s14d4               1.60
# 37     Mo  Molybdenum      96.000            [Kr]5s14d5               2.16
# 38     Tc  Technetium      97.907            [Kr]5s24d5               1.90
# 39     Ru   Ruthenium     101.100            [Kr]5s14d7               2.20
# 40     Rh     Rhodium     102.905            [Kr]5s14d8               2.28
# 41     Pd   Palladium     106.400              [Kr]4d10               2.20
# 42     Ag      Silver     107.868           [Kr]5s14d10               1.93
# 44     In      Indium     114.820        [Kr]5s24d105p1               1.78
# 45     Sn         Tin     118.710        [Kr]5s24d105p2               1.96
# 46     Sb    Antimony     121.760        [Kr]5s24d105p3               2.05
# 47     Te   Tellurium     127.600        [Kr]5s24d105p4               2.10
# 48      I      Iodine     126.904        [Kr]5s24d105p5               2.66
# 49     Cs      Cesium     132.905               [Xe]6s1               0.79
# 51     Ta    Tantalum     180.947        [Xe]6s24f145d3               1.50
# 52      W    Tungsten     183.800        [Xe]6s24f145d4               2.36
# 53     Re     Rhenium     186.210        [Xe]6s24f145d5               1.90
# 54     Os      Osmium     190.200        [Xe]6s24f145d6               2.20
# 55     Ir     Iridium     192.220        [Xe]6s24f145d7               2.20
# 56     Pt    Platinum     195.080        [Xe]6s14f145d9               2.28
# 57     Au        Gold     196.966       [Xe]6s14f145d10               2.54
# 59     Tl    Thallium     204.383    [Xe]6s24f145d106p1               1.62
# 60     Pb        Lead     207.000    [Xe]6s24f145d106p2               2.33
# 61     Bi     Bismuth     208.980    [Xe]6s24f145d106p3               2.02
# 62     Po    Polonium     208.982    [Xe]6s24f145d106p4               2.00
#
#     AtomicRadius  IonizationEnergy  ElectronAffinity OxidationStates  \
# 0            120            13.598             0.754            +1-1
# 1            182             5.392             0.618               1
# 3            192             8.298             0.277               3
# 4            170            11.260             1.263          +4+2-4
# 6            152            13.618             1.461              -2
# 7            135            17.423             3.339              -1
# 8            227             5.139             0.548               1
# 10           184             5.986             0.441               3
# 11           210             8.152             1.385          +4+2-4
# 12           180            10.487             0.746          +5+3-3
# 13           180            10.360             2.077          +6+4-2
# 14           175            12.968             3.617        +7+5+1-1
# 15           275             4.341             0.501               1
# 17           211             6.561             0.188               3
# 18           187             6.828             0.079          +4+3+2
# 19           179             6.746             0.525        +5+4+3+2
# 20           189             6.767             0.666          +6+3+2
# 22           194             7.902             0.163            +3+2
# 23           192             7.881             0.661            +3+2
# 24           163             7.640             1.156            +3+2
# 25           140             7.726             1.228            +2+1
# 27           187             5.999             0.300               3
# 28           211             7.900             1.350            +4+2
# 29           185             9.815             0.810          +5+3-3
# 30           190             9.752             2.021          +6+4-2
# 31           183            11.814             3.365          +5+1-1
# 32           303             4.177             0.468               1
# 34           219             6.217             0.307               3
# 35           186             6.634             0.426               4
# 36           207             6.759             0.893            +5+3
# 37           209             7.092             0.746               6
# 38           209             7.280             0.550          +7+6+4
# 39           207             7.361             1.050               3
# 40           195             7.459             1.137               3
# 41           202             8.337             0.557            +3+2
# 42           172             7.576             1.302               1
# 44           193             5.786             0.300               3
# 45           217             7.344             1.200            +4+2
# 46           206             8.640             1.070          +5+3-3
# 47           206             9.010             1.971          +6+4-2
# 48           198            10.451             3.059        +7+5+1-1
# 49           343             3.894             0.472               1
# 51           217             7.890             0.322               5
# 52           210             7.980             0.815               6
# 53           217             7.880             0.150          +7+6+4
# 54           216             8.700             1.100            +4+3
# 55           202             9.100             1.565            +4+3
# 56           209             9.000             2.128            +4+2
# 57           166             9.226             2.309            +3+1
# 59           196             6.108             0.200            +3+1
# 60           202             7.417             0.360            +4+2
# 61           207             7.289             0.946            +5+3
# 62           197             8.417             1.900            +4+2
#
#    StandardState  MeltingPoint  BoilingPoint    Density            GroupBlock  \
# 0            Gas        13.810         20.28   0.000090              Nonmetal
# 1          Solid       453.650       1615.00   0.534000           Alkalimetal
# 3          Solid      2348.000       4273.00   2.370000             Metalloid
# 4          Solid      3823.000       4098.00   2.267000              Nonmetal
# 6            Gas        54.360         90.20   0.001429              Nonmetal
# 7            Gas        53.530         85.03   0.001696               Halogen
# 8          Solid       370.950       1156.00   0.970000           Alkalimetal
# 10         Solid       933.437       2792.00   2.700000  Post-transitionmetal
# 11         Solid      1687.000       3538.00   2.329000             Metalloid
# 12         Solid       317.300        553.65   1.820000              Nonmetal
# 13         Solid       388.360        717.75   2.067000              Nonmetal
# 14           Gas       171.650        239.11   0.003214               Halogen
# 15         Solid       336.530       1032.00   0.890000           Alkalimetal
# 17         Solid      1814.000       3109.00   2.990000       Transitionmetal
# 18         Solid      1941.000       3560.00   4.500000       Transitionmetal
# 19         Solid      2183.000       3680.00   6.000000       Transitionmetal
# 20         Solid      2180.000       2944.00   7.150000       Transitionmetal
# 22         Solid      1811.000       3134.00   7.874000       Transitionmetal
# 23         Solid      1768.000       3200.00   8.860000       Transitionmetal
# 24         Solid      1728.000       3186.00   8.912000       Transitionmetal
# 25         Solid      1357.770       2835.00   8.933000       Transitionmetal
# 27         Solid       302.910       2477.00   5.910000  Post-transitionmetal
# 28         Solid      1211.400       3106.00   5.323000             Metalloid
# 29         Solid      1090.000        887.00   5.776000             Metalloid
# 30         Solid       493.650        958.00   4.809000              Nonmetal
# 31        Liquid       265.950        331.95   3.110000               Halogen
# 32         Solid       312.460        961.00   1.530000           Alkalimetal
# 34         Solid      1795.000       3618.00   4.470000       Transitionmetal
# 35         Solid      2128.000       4682.00   6.520000       Transitionmetal
# 36         Solid      2750.000       5017.00   8.570000       Transitionmetal
# 37         Solid      2896.000       4912.00  10.200000       Transitionmetal
# 38         Solid      2430.000       4538.00  11.000000       Transitionmetal
# 39         Solid      2607.000       4423.00  12.100000       Transitionmetal
# 40         Solid      2237.000       3968.00  12.400000       Transitionmetal
# 41         Solid      1828.050       3236.00  12.000000       Transitionmetal
# 42         Solid      1234.930       2435.00  10.501000       Transitionmetal
# 44         Solid       429.750       2345.00   7.310000  Post-transitionmetal
# 45         Solid       505.080       2875.00   7.287000  Post-transitionmetal
# 46         Solid       903.780       1860.00   6.685000             Metalloid
# 47         Solid       722.660       1261.00   6.232000             Metalloid
# 48         Solid       386.850        457.55   4.930000               Halogen
# 49         Solid       301.590        944.00   1.930000           Alkalimetal
# 51         Solid      3290.000       5731.00  16.400000       Transitionmetal
# 52         Solid      3695.000       5828.00  19.300000       Transitionmetal
# 53         Solid      3459.000       5869.00  20.800000       Transitionmetal
# 54         Solid      3306.000       5285.00  22.570000       Transitionmetal
# 55         Solid      2719.000       4701.00  22.420000       Transitionmetal
# 56         Solid      2041.550       4098.00  21.460000       Transitionmetal
# 57         Solid      1337.330       3129.00  19.282000       Transitionmetal
# 59         Solid       577.000       1746.00  11.800000  Post-transitionmetal
# 60         Solid       600.610       2022.00  11.342000  Post-transitionmetal
# 61         Solid       544.550       1837.00   9.807000  Post-transitionmetal
# 62         Solid       527.000       1235.00   9.320000             Metalloid
#
#    YearDiscovered" "AtomicNumber
# 0            1766"            "1
# 1            1817"            "3
# 3            1808"            "5
# 4         Ancient"            "6
# 6            1774"            "8
# 7            1670"            "9
# 8            1807"           "11
# 10        Ancient"           "13
# 11           1854"           "14
# 12           1669"           "15
# 13        Ancient"           "16
# 14           1774"           "17
# 15           1807"           "19
# 17           1879"           "21
# 18           1791"           "22
# 19           1801"           "23
# 20           1797"           "24
# 22        Ancient"           "26
# 23           1735"           "27
# 24           1751"           "28
# 25        Ancient"           "29
# 27           1875"           "31
# 28           1886"           "32
# 29        Ancient"           "33
# 30           1817"           "34
# 31           1826"           "35
# 32           1861"           "37
# 34           1794"           "39
# 35           1789"           "40
# 36           1801"           "41
# 37           1778"           "42
# 38           1937"           "43
# 39           1827"           "44
# 40           1803"           "45
# 41           1803"           "46
# 42        Ancient"           "47
# 44           1863"           "49
# 45        Ancient"           "50
# 46        Ancient"           "51
# 47           1782"           "52
# 48           1811"           "53
# 49           1860"           "55
# 51           1802"           "73
# 52           1783"           "74
# 53           1925"           "75
# 54           1803"           "76
# 55           1803"           "77
# 56           1735"           "78
# 57        Ancient"           "79
# 59           1861"           "81
# 60        Ancient"           "82
# 61           1753"           "83
# 62           1898"           "84

# %%
raw_data.reset_index(drop=True, inplace=True)
raw_data.set_index(raw_data["Symbol"], drop=True, inplace= True)
raw_data
# Out:
#        Symbol        Name  AtomicMass ElectronConfiguration  \
# Symbol
# H           H    Hydrogen       1.008                   1s1
# Li         Li     Lithium       7.000               [He]2s1
# B           B       Boron      10.810            [He]2s22p1
# C           C      Carbon      12.011            [He]2s22p2
# O           O      Oxygen      15.999            [He]2s22p4
# F           F    Fluorine      18.998            [He]2s22p5
# Na         Na      Sodium      22.989               [Ne]3s1
# Al         Al    Aluminum      26.981            [Ne]3s23p1
# Si         Si     Silicon      28.085            [Ne]3s23p2
# P           P  Phosphorus      30.973            [Ne]3s23p3
# S           S      Sulfur      32.070            [Ne]3s23p4
# Cl         Cl    Chlorine      35.450            [Ne]3s23p5
# K           K   Potassium      39.098               [Ar]4s1
# Sc         Sc    Scandium      44.955            [Ar]4s23d1
# Ti         Ti    Titanium      47.870            [Ar]4s23d2
# V           V    Vanadium      50.941            [Ar]4s23d3
# Cr         Cr    Chromium      51.996            [Ar]3d54s1
# Fe         Fe        Iron      55.840            [Ar]4s23d6
# Co         Co      Cobalt      58.933            [Ar]4s23d7
# Ni         Ni      Nickel      58.693            [Ar]4s23d8
# Cu         Cu      Copper      63.550           [Ar]4s13d10
# Ga         Ga     Gallium      69.720        [Ar]4s23d104p1
# Ge         Ge   Germanium      72.630        [Ar]4s23d104p2
# As         As     Arsenic      74.921        [Ar]4s23d104p3
# Se         Se    Selenium      78.970        [Ar]4s23d104p4
# Br         Br     Bromine      79.900        [Ar]4s23d104p5
# Rb         Rb    Rubidium      85.468               [Kr]5s1
# Y           Y     Yttrium      88.905            [Kr]5s24d1
# Zr         Zr   Zirconium      91.220            [Kr]5s24d2
# Nb         Nb     Niobium      92.906            [Kr]5s14d4
# Mo         Mo  Molybdenum      96.000            [Kr]5s14d5
# Tc         Tc  Technetium      97.907            [Kr]5s24d5
# Ru         Ru   Ruthenium     101.100            [Kr]5s14d7
# Rh         Rh     Rhodium     102.905            [Kr]5s14d8
# Pd         Pd   Palladium     106.400              [Kr]4d10
# Ag         Ag      Silver     107.868           [Kr]5s14d10
# In         In      Indium     114.820        [Kr]5s24d105p1
# Sn         Sn         Tin     118.710        [Kr]5s24d105p2
# Sb         Sb    Antimony     121.760        [Kr]5s24d105p3
# Te         Te   Tellurium     127.600        [Kr]5s24d105p4
# I           I      Iodine     126.904        [Kr]5s24d105p5
# Cs         Cs      Cesium     132.905               [Xe]6s1
# Ta         Ta    Tantalum     180.947        [Xe]6s24f145d3
# W           W    Tungsten     183.800        [Xe]6s24f145d4
# Re         Re     Rhenium     186.210        [Xe]6s24f145d5
# Os         Os      Osmium     190.200        [Xe]6s24f145d6
# Ir         Ir     Iridium     192.220        [Xe]6s24f145d7
# Pt         Pt    Platinum     195.080        [Xe]6s14f145d9
# Au         Au        Gold     196.966       [Xe]6s14f145d10
# Tl         Tl    Thallium     204.383    [Xe]6s24f145d106p1
# Pb         Pb        Lead     207.000    [Xe]6s24f145d106p2
# Bi         Bi     Bismuth     208.980    [Xe]6s24f145d106p3
# Po         Po    Polonium     208.982    [Xe]6s24f145d106p4
#
#         Electronegativity  AtomicRadius  IonizationEnergy  ElectronAffinity  \
# Symbol
# H                    2.20           120            13.598             0.754
# Li                   0.98           182             5.392             0.618
# B                    2.04           192             8.298             0.277
# C                    2.55           170            11.260             1.263
# O                    3.44           152            13.618             1.461
# F                    3.98           135            17.423             3.339
# Na                   0.93           227             5.139             0.548
# Al                   1.61           184             5.986             0.441
# Si                   1.90           210             8.152             1.385
# P                    2.19           180            10.487             0.746
# S                    2.58           180            10.360             2.077
# Cl                   3.16           175            12.968             3.617
# K                    0.82           275             4.341             0.501
# Sc                   1.36           211             6.561             0.188
# Ti                   1.54           187             6.828             0.079
# V                    1.63           179             6.746             0.525
# Cr                   1.66           189             6.767             0.666
# Fe                   1.83           194             7.902             0.163
# Co                   1.88           192             7.881             0.661
# Ni                   1.91           163             7.640             1.156
# Cu                   1.90           140             7.726             1.228
# Ga                   1.81           187             5.999             0.300
# Ge                   2.01           211             7.900             1.350
# As                   2.18           185             9.815             0.810
# Se                   2.55           190             9.752             2.021
# Br                   2.96           183            11.814             3.365
# Rb                   0.82           303             4.177             0.468
# Y                    1.22           219             6.217             0.307
# Zr                   1.33           186             6.634             0.426
# Nb                   1.60           207             6.759             0.893
# Mo                   2.16           209             7.092             0.746
# Tc                   1.90           209             7.280             0.550
# Ru                   2.20           207             7.361             1.050
# Rh                   2.28           195             7.459             1.137
# Pd                   2.20           202             8.337             0.557
# Ag                   1.93           172             7.576             1.302
# In                   1.78           193             5.786             0.300
# Sn                   1.96           217             7.344             1.200
# Sb                   2.05           206             8.640             1.070
# Te                   2.10           206             9.010             1.971
# I                    2.66           198            10.451             3.059
# Cs                   0.79           343             3.894             0.472
# Ta                   1.50           217             7.890             0.322
# W                    2.36           210             7.980             0.815
# Re                   1.90           217             7.880             0.150
# Os                   2.20           216             8.700             1.100
# Ir                   2.20           202             9.100             1.565
# Pt                   2.28           209             9.000             2.128
# Au                   2.54           166             9.226             2.309
# Tl                   1.62           196             6.108             0.200
# Pb                   2.33           202             7.417             0.360
# Bi                   2.02           207             7.289             0.946
# Po                   2.00           197             8.417             1.900
#
#        OxidationStates StandardState  MeltingPoint  BoilingPoint    Density  \
# Symbol
# H                 +1-1           Gas        13.810         20.28   0.000090
# Li                   1         Solid       453.650       1615.00   0.534000
# B                    3         Solid      2348.000       4273.00   2.370000
# C               +4+2-4         Solid      3823.000       4098.00   2.267000
# O                   -2           Gas        54.360         90.20   0.001429
# F                   -1           Gas        53.530         85.03   0.001696
# Na                   1         Solid       370.950       1156.00   0.970000
# Al                   3         Solid       933.437       2792.00   2.700000
# Si              +4+2-4         Solid      1687.000       3538.00   2.329000
# P               +5+3-3         Solid       317.300        553.65   1.820000
# S               +6+4-2         Solid       388.360        717.75   2.067000
# Cl            +7+5+1-1           Gas       171.650        239.11   0.003214
# K                    1         Solid       336.530       1032.00   0.890000
# Sc                   3         Solid      1814.000       3109.00   2.990000
# Ti              +4+3+2         Solid      1941.000       3560.00   4.500000
# V             +5+4+3+2         Solid      2183.000       3680.00   6.000000
# Cr              +6+3+2         Solid      2180.000       2944.00   7.150000
# Fe                +3+2         Solid      1811.000       3134.00   7.874000
# Co                +3+2         Solid      1768.000       3200.00   8.860000
# Ni                +3+2         Solid      1728.000       3186.00   8.912000
# Cu                +2+1         Solid      1357.770       2835.00   8.933000
# Ga                   3         Solid       302.910       2477.00   5.910000
# Ge                +4+2         Solid      1211.400       3106.00   5.323000
# As              +5+3-3         Solid      1090.000        887.00   5.776000
# Se              +6+4-2         Solid       493.650        958.00   4.809000
# Br              +5+1-1        Liquid       265.950        331.95   3.110000
# Rb                   1         Solid       312.460        961.00   1.530000
# Y                    3         Solid      1795.000       3618.00   4.470000
# Zr                   4         Solid      2128.000       4682.00   6.520000
# Nb                +5+3         Solid      2750.000       5017.00   8.570000
# Mo                   6         Solid      2896.000       4912.00  10.200000
# Tc              +7+6+4         Solid      2430.000       4538.00  11.000000
# Ru                   3         Solid      2607.000       4423.00  12.100000
# Rh                   3         Solid      2237.000       3968.00  12.400000
# Pd                +3+2         Solid      1828.050       3236.00  12.000000
# Ag                   1         Solid      1234.930       2435.00  10.501000
# In                   3         Solid       429.750       2345.00   7.310000
# Sn                +4+2         Solid       505.080       2875.00   7.287000
# Sb              +5+3-3         Solid       903.780       1860.00   6.685000
# Te              +6+4-2         Solid       722.660       1261.00   6.232000
# I             +7+5+1-1         Solid       386.850        457.55   4.930000
# Cs                   1         Solid       301.590        944.00   1.930000
# Ta                   5         Solid      3290.000       5731.00  16.400000
# W                    6         Solid      3695.000       5828.00  19.300000
# Re              +7+6+4         Solid      3459.000       5869.00  20.800000
# Os                +4+3         Solid      3306.000       5285.00  22.570000
# Ir                +4+3         Solid      2719.000       4701.00  22.420000
# Pt                +4+2         Solid      2041.550       4098.00  21.460000
# Au                +3+1         Solid      1337.330       3129.00  19.282000
# Tl                +3+1         Solid       577.000       1746.00  11.800000
# Pb                +4+2         Solid       600.610       2022.00  11.342000
# Bi                +5+3         Solid       544.550       1837.00   9.807000
# Po                +4+2         Solid       527.000       1235.00   9.320000
#
#                   GroupBlock YearDiscovered" "AtomicNumber
# Symbol
# H                   Nonmetal           1766"            "1
# Li               Alkalimetal           1817"            "3
# B                  Metalloid           1808"            "5
# C                   Nonmetal        Ancient"            "6
# O                   Nonmetal           1774"            "8
# F                    Halogen           1670"            "9
# Na               Alkalimetal           1807"           "11
# Al      Post-transitionmetal        Ancient"           "13
# Si                 Metalloid           1854"           "14
# P                   Nonmetal           1669"           "15
# S                   Nonmetal        Ancient"           "16
# Cl                   Halogen           1774"           "17
# K                Alkalimetal           1807"           "19
# Sc           Transitionmetal           1879"           "21
# Ti           Transitionmetal           1791"           "22
# V            Transitionmetal           1801"           "23
# Cr           Transitionmetal           1797"           "24
# Fe           Transitionmetal        Ancient"           "26
# Co           Transitionmetal           1735"           "27
# Ni           Transitionmetal           1751"           "28
# Cu           Transitionmetal        Ancient"           "29
# Ga      Post-transitionmetal           1875"           "31
# Ge                 Metalloid           1886"           "32
# As                 Metalloid        Ancient"           "33
# Se                  Nonmetal           1817"           "34
# Br                   Halogen           1826"           "35
# Rb               Alkalimetal           1861"           "37
# Y            Transitionmetal           1794"           "39
# Zr           Transitionmetal           1789"           "40
# Nb           Transitionmetal           1801"           "41
# Mo           Transitionmetal           1778"           "42
# Tc           Transitionmetal           1937"           "43
# Ru           Transitionmetal           1827"           "44
# Rh           Transitionmetal           1803"           "45
# Pd           Transitionmetal           1803"           "46
# Ag           Transitionmetal        Ancient"           "47
# In      Post-transitionmetal           1863"           "49
# Sn      Post-transitionmetal        Ancient"           "50
# Sb                 Metalloid        Ancient"           "51
# Te                 Metalloid           1782"           "52
# I                    Halogen           1811"           "53
# Cs               Alkalimetal           1860"           "55
# Ta           Transitionmetal           1802"           "73
# W            Transitionmetal           1783"           "74
# Re           Transitionmetal           1925"           "75
# Os           Transitionmetal           1803"           "76
# Ir           Transitionmetal           1803"           "77
# Pt           Transitionmetal           1735"           "78
# Au           Transitionmetal        Ancient"           "79
# Tl      Post-transitionmetal           1861"           "81
# Pb      Post-transitionmetal        Ancient"           "82
# Bi      Post-transitionmetal           1753"           "83
# Po                 Metalloid           1898"           "84

# %% [markdown]
# $\quad$**任务1**: 完成函数`preprocess_chem_elements`的编写, 输入:
# - `raw_data`: 原始数据(缺失值已丢弃, 无需额外处理), 为一个`pd.DataFrame`对象;
# - `feature_cols`: 一个列表, 用于下游降维/聚类任务的特征列名;
# - `idx_col`: 字符串, 用作新的数据表的列名.
#
# 要求: (1)根据给定的`idx_col`重新设置表格索引, 并将原索引丢弃; (2) 挑选出原始数据中的`feature_cols`列、并作均值-方差归一化. 最终返回一个处理好的、只含`feature_cols`列的(归一化)数据表, 索引按`idx_col`确定.

# %% [markdown]
# ### 提示
# - 索引重置方法可以参考[`df.reset_index`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html#pandas-dataframe-reset-index)方法;
# - 归一化可以参考[`sklearn.preprocessing.StandardScaler`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn-preprocessing-standardscaler)模块;
# - 可以复习前2次上机作业对于`pandas`库的介绍.

# %%
from typing import List
from sklearn.preprocessing import StandardScaler

def preprocess_chem_elements(
    raw_data: pd.DataFrame, feature_cols: List[str],
    idx_col: str="Symbol"
) -> pd.DataFrame:
    ### BEGIN YOUR SOLUTION ###
    raw_data.reset_index(drop=True, inplace=True)
    new_data = raw_data[feature_cols]
    scaler = StandardScaler()
    standard_data = pd.DataFrame(scaler.fit_transform(new_data), index=raw_data[idx_col])
    standard_data
    return standard_data
    ### END YOUR SOLUTION ###

# %% [markdown]
# $\quad$完成任务1后, 请运行下面的代码块, 给出处理好的数据表`X`. 我们所选取的特征包括:
# - 原子质量`AtomicMass`, 单位u;
# - 原子半径`AtomicRadius`, 采取[van der Waals半径](https://en.wikipedia.org/wiki/Van_der_Waals_radius), 单位pm;
# - 电离能`IonizationEnery`, 单位eV;
# - 电子亲合能`ElectronAffinity`, 单位eV;
# - 电负性`Electronegativity`, 采取[Pauling标度](https://en.wikipedia.org/wiki/Electronegativity#Pauling_electronegativity);
# - 熔点`MeltingPoint`, 单位K;
# - 沸点`BoilingPoint`, 单位K;
# - 单质密度`Density`, 单位g/mL.

# %%
feature_cols = [
    "AtomicMass",
    "AtomicRadius",
    "IonizationEnergy",
    "ElectronAffinity",
    "Electronegativity",
    "MeltingPoint",
    "BoilingPoint",
    "Density"
]
X = preprocess_chem_elements(
    raw_data,
    feature_cols=feature_cols
)
X
# Out:
#                0         1         2         3         4         5         6  \
# Symbol
# H      -1.484785 -2.243779  2.194844 -0.369949  0.341005 -1.303907 -1.613774
# Li     -1.388654 -0.464566 -1.127539 -0.527923 -1.650809 -0.892769 -0.650228
# B      -1.327530 -0.177596  0.049020 -0.924018  0.079783  0.877964  0.955764
# C      -1.308262 -0.808930  1.248252  0.221290  0.912427  2.256712  0.850027
# O      -1.244282 -1.325476  2.202941  0.451281  2.365472 -1.266003 -1.571528
# F      -1.196168 -1.813325  3.743481  2.632710  3.247094 -1.266779 -1.574651
# Na     -1.132140  0.826798 -1.229972 -0.609233 -1.732441 -0.970072 -0.927560
# Al     -1.068096 -0.407172 -0.887045 -0.733521 -0.622249 -0.444291  0.060928
# Si     -1.050384  0.338949 -0.010091  0.363002 -0.148785  0.260098  0.511669
# P      -1.004051 -0.521960  0.935286 -0.379242  0.324679 -1.020221 -1.291506
# S      -0.986452 -0.521960  0.883867  1.166808  0.961406 -0.953798 -1.192355
# Cl     -0.932226 -0.665445  1.939774  2.955626  1.908334 -1.156367 -1.481555
# K      -0.873700  2.204253 -1.553060 -0.663826 -1.912031 -1.002246 -1.002482
# Sc     -0.779736  0.367646 -0.654243 -1.027398 -1.030408  0.378810  0.252463
# Ti     -0.732970 -0.321081 -0.546142 -1.154009 -0.736534  0.497523  0.524962
# V      -0.683701 -0.550657 -0.579342 -0.635949 -0.589597  0.723731  0.597467
# Cr     -0.666775 -0.263687 -0.570840 -0.472167 -0.540618  0.720927  0.152768
# Fe     -0.605106 -0.120202 -0.111309 -1.056437 -0.263070  0.376006  0.267568
# Co     -0.555484 -0.177596 -0.119812 -0.477975 -0.181438  0.335812  0.307446
# Ni     -0.559334 -1.009809 -0.217386  0.097002 -0.132459  0.298422  0.298987
# Cu     -0.481413 -1.669840 -0.182567  0.180635 -0.148785 -0.047648  0.086909
# Ga     -0.382426 -0.321081 -0.881782 -0.897302 -0.295722 -1.033672 -0.129398
# Ge     -0.335740  0.367646 -0.112119  0.322347  0.030804 -0.184466  0.250650
# As     -0.298986 -0.378475  0.663212 -0.304901  0.308352 -0.297944 -1.090093
# Se     -0.234027 -0.234990  0.637705  1.101760  0.912427 -0.855379 -1.047194
# Br     -0.219107 -0.435869  1.472552  2.662911  1.581807 -1.068221 -1.425460
# Rb     -0.129778  3.007769 -1.619459 -0.702158 -1.912031 -1.024746 -1.045381
# Y      -0.074638  0.597222 -0.793519 -0.889171 -1.258977  0.361050  0.560006
# Zr     -0.037498 -0.349778 -0.624688 -0.750944 -1.079387  0.672320  1.202886
# Nb     -0.010449  0.252858 -0.574079 -0.208491 -0.638576  1.253731  1.405296
# Mo      0.039189  0.310252 -0.439256 -0.379242  0.275700  1.390204  1.341854
# Tc      0.069783  0.310252 -0.363140 -0.606909 -0.148785  0.954613  1.115879
# Ru      0.121009  0.252858 -0.330345 -0.026124  0.341005  1.120063  1.046395
# Rh      0.149967 -0.091505 -0.290668  0.074932  0.471616  0.774207  0.771480
# Pd      0.206038  0.109373  0.064810 -0.598779  0.341005  0.391944  0.329198
# Ag      0.229589 -0.751536 -0.243298  0.266591 -0.099806 -0.162472 -0.154775
# In      0.341121 -0.148899 -0.968019 -0.897302 -0.344702 -0.915109 -0.209154
# Sn      0.403529  0.539828 -0.337228  0.148111 -0.050827 -0.844695  0.111078
# Sb      0.452461  0.224161  0.187486 -0.002893  0.096110 -0.472013 -0.502196
# Te      0.546153  0.224161  0.337289  1.043682  0.177742 -0.641313 -0.864118
# I       0.534987 -0.005415  0.920710  2.307470  1.092017 -0.955210 -1.349571
# Cs      0.631262  4.155648 -1.734038 -0.697512 -1.961010 -1.034906 -1.055653
# Ta      1.402009  0.539828 -0.116168 -0.871748 -0.801839  1.758493  1.836702
# W       1.447780  0.338949 -0.079729 -0.299093  0.602227  2.137065  1.895311
# Re      1.486444  0.539828 -0.120217 -1.071538 -0.148785  1.916465  1.920084
# Os      1.550456  0.511131  0.211779  0.031954  0.341005  1.773449  1.567225
# Ir      1.582864  0.109373  0.373728  0.572084  0.341005  1.224754  1.214366
# Pt      1.628747  0.310252  0.333241  1.226048  0.471616  0.591512  0.850027
# Au      1.659004 -0.923718  0.424742  1.436293  0.896101 -0.066754  0.264547
# Tl      1.777997 -0.062808 -0.837650 -1.013459 -0.605923 -0.777468 -0.571076
# Pb      1.819982  0.109373 -0.307672 -0.827608  0.553247 -0.755399 -0.404314
# Bi      1.851747  0.252858 -0.359496 -0.146928  0.047131 -0.807801 -0.516093
# Po      1.851779 -0.034112  0.097200  0.961210  0.014478 -0.824206 -0.879827
#
#                7
# Symbol
# H      -1.241627
# Li     -1.154716
# B      -0.855850
# C      -0.872616
# O      -1.241409
# F      -1.241365
# Na     -1.083744
# Al     -0.802132
# Si     -0.862524
# P      -0.945379
# S      -0.905173
# Cl     -1.241118
# K      -1.096766
# Sc     -0.754925
# Ti     -0.509126
# V      -0.264954
# Cr     -0.077755
# Fe      0.040098
# Co      0.200600
# Ni      0.209065
# Cu      0.212483
# Ga     -0.279604
# Ge     -0.375157
# As     -0.301417
# Se     -0.458826
# Br     -0.735392
# Rb     -0.992586
# Y      -0.514009
# Zr     -0.180308
# Nb      0.153394
# Mo      0.418727
# Tc      0.548952
# Ru      0.728012
# Rh      0.776846
# Pd      0.711734
# Ag      0.467724
# In     -0.051710
# Sn     -0.055454
# Sb     -0.153449
# Te     -0.227189
# I      -0.439130
# Cs     -0.927474
# Ta      1.427971
# W       1.900037
# Re      2.144208
# Os      2.432331
# Ir      2.407914
# Pt      2.251644
# Au      1.897107
# Tl      0.679177
# Pb      0.604623
# Bi      0.354754
# Po      0.275480

# %% [markdown]
# # 数据的主元分析
#
# $\quad$在本节, 我们以PCA模型进行数据降维, 并对前两个主元作相应的可视化分析.
#
# $\quad$**任务2**: 完成函数`get_pc_info`的编写. 输入数据`X`和PCA组分数`n_components`, 对数据`X`作PCA模型的训练与变换, 并提取相应的信息. 返回一个三元组:
# - 降维后的数据`X_reduced`, 形状应为`(n_samples, n_components)`;
# - 各个主元的方差解释比例`explained_variance_ratio`;
# - 主元变换矩阵`components`, 形状为`(n_components, n_features)`.

# %%
from typing import Tuple
import numpy as np
from sklearn.decomposition import PCA

def get_pc_info(
    X: pd.DataFrame, n_components: int=2
) -> Tuple[np.array, np.array, np.array]:
    ### BEGIN YOUR SOLUTION ###
    pca = PCA(n_components=n_components)
    X_reduced = pca.fit_transform(X)
    return (X_reduced, pca.explained_variance_, pca.components_)
    ### END YOUR SOLUTION ###

# %% [markdown]
# $\quad$完成任务2后, 请运行下面的代码进行检查.

# %%
X_reduced, explained_variance_ratio, components = get_pc_info(X)
X_reduced.shape, explained_variance_ratio.shape, components.shape
# Out:
# ((53, 2), (2,), (2, 8))

# %% [markdown]
# $\quad$**任务3**: 运行下面两个代码块, 根据给定的函数`plot_pc1_pc2`完成可视化分析, 在对应的答题区回答下面的问题:
#
# - 观察左图, 这是二维隐空间中样本的散点分布. 回答: 四个象限的元素各自以哪一类为主? 请作出分配: (a) 过渡金属元素; (b) 主族金属元素; (c) 主族非金属元素; (d) 卤素.
# - 观察右图, 这是将变换矩阵的每一列(作为二维向量)画成矢量给出的**载荷图**(loading plot). 两个向量朝向相近表明它们之间存在某种内禀共性. 请回答:
#   - 第三象限聚集的那些原始特征大多与元素的什么性质有关? 请作出选择: (a) 原子聚集行为; (b) 电子吸引能力.
#   - 第四象限聚集的那些原始特征大多与元素的什么性质有关? 请作出选择: (a) 原子聚集行为; (b) 电子吸引能力.
#   - 第二象限只分布有一个原始特征, 它与第四象限的那些特征具有较强的“负相关性”, 请作出简单解释.

# %%
from matplotlib import pyplot as plt

def plot_pc1_pc2(X_reduced, explained_variance_ratio, components, idxs, feature_cols):
    fig, (ax1, ax2) = plt.subplots(1, 2, layout="constrained", figsize=(10, 4))
    # sample plot
    ax1.scatter(X_reduced[:, 0], X_reduced[:, 1])
    ax1.set_aspect('equal', adjustable='box')
    ax1.axhline(y=0, linestyle="--")
    ax1.axvline(x=0, linestyle="--")
    for i, idx in enumerate(idxs):
        ax1.annotate(idx, (X_reduced[i, 0], X_reduced[i, 1]))
    # loading plot
    ax2.add_patch(plt.Circle((0, 0), 1.0, fill=False, edgecolor="red", linestyle="--"))
    n_features = components.shape[1]
    for i in range(n_features):
        ax2.arrow(0, 0, components[0, i], components[1, i], head_width=0.05)
        ax2.annotate(feature_cols[i], (components[0, i] - 0.25, components[1, i]), fontsize=8)
    ax2.axhline(y=0, linestyle="--")
    ax2.axvline(x=0, linestyle="--")
    ax2.set_aspect('equal', adjustable='box')
    # title, axes, and annotation
    ratio1, ratio2 = explained_variance_ratio
    ax1.set_title("Samples in latent space")
    ax1.set_xlabel(f"PC1({ratio1 * 100:.2f}%)")
    ax1.set_ylabel(f"PC2({ratio2 * 100:.2f}%)")
    ax2.set_title("Loading plot")
    ax2.set_xlabel(f"PC1({ratio1 * 100:.2f}%)")
    ax2.set_ylabel(f"PC2({ratio2 * 100:.2f}%)")
    plt.show()

# %%
plot_pc1_pc2(X_reduced, explained_variance_ratio, components, X.index, feature_cols)

### 任务3答题区(另起一行时请记得加注释符号#) ###
### BEGIN YOUR SOLUTION ###
# 第一象限主族非金属元素， 第二象限主族金属元素， 第三象限过渡金属元素， 第四象限卤素
# 原子聚集行为
# 电子吸引能力
# 原子半径在同一周期内和电负性具有较强的负相关性
### END YOUR SOLUTION

# %% [markdown]
# # 隐空间上的聚类分析
#
# $\quad$我们在降维后的隐空间上进行k-means聚类, 并对聚类结果进行评估. 具体试验的降维算法将包括PCA、Isomap与t-SNE, 均控制为降到3维. 由于聚类分析是非监督的, 它没有类似“准确率”这样的评估指标, 本节我们采取的指标有两个:
# - (调整的)随机指数相似性, 以[`adjusted_rand_score`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html#sklearn.metrics.adjusted_rand_score)方法实现. 这一指标适合本例的情形, 即存在一组真实标签作为对照. 该指标大致可以理解为真实标签与预测标签在“分配结构”上的相似性.
# - **轮廓系数**(silhouette coefficient), 以[`silhouette_score`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html#sklearn-metrics-silhouette-score)方法实现. 该指标大致可以理解为簇间轮廓的清晰程度(的样本平均), 计算公式为:
#   $$
#   S := \frac{1}{N}\sum_{n=1}^N{\frac{b_n - a_n}{\max{\{a_n, b_n\}}}},
#   $$
#   其中, $n = 1, \dots, N$遍历所有数据样本, $a_n, b_n$分别表示样本$n$到点$A_n, B_n$的距离. 其中, 点$A_n$为样本$n$所在的簇中心, 点$B_n$为样本$n$所不在的、最近邻的簇中心.

# %% [markdown]
# **任务4**: 完成函数`cluster_on_latent_space`的编写, 输入:
# - `X`, 待降维的数据;
# - `reduction_model`, 用于降维的模型;
# - `y_true`, 真实标签, 本例取为原始表格中的`GroupBlock`一列, 代表元素所属的类别(例如: 碱金属、过渡金属、非金属, 等等);
# - `n_clusters`: 簇的个数. 为了与真实标签保持统一, 本例默认值取为7, 无需修改.
# - `random_state`: 用于运行k-means算法的随机数种子. 默认取42, 无需修改.
#
# 要求对给定的数据`X`利用`reduction_model`进行降维, 再以k-means方法进行聚类分析, 并对聚类结果进行评估. 返回一个二元组: 随机指数相似性、轮廓系数.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, silhouette_score

def cluster_on_latent_space(
    X, reduction_model, y_true,
    n_clusters: int=7, random_state: int=42
) -> Tuple[float, float]:
    ### BEGIN YOUR SOLUTION ###
    X_reduced = reduction_model.fit_transform(X)
    y_pred = KMeans(n_clusters=n_clusters, random_state=random_state).fit_predict(X_reduced)
    return (adjusted_rand_score(y_true, y_pred), silhouette_score(X_reduced, y_pred))
    ### END YOUR SOLUTION ###

# %% [markdown]
# $\quad$完成任务3后, 你可以运行下面的代码块, 对PCA、Isomap和t-SNE的聚类结果进行综合评估.

# %%
from sklearn.manifold import Isomap, TSNE
from sklearn.preprocessing import LabelEncoder

metrics = pd.DataFrame(columns=["rand_acc", "silhouette_coeff"], index=["PCA", "Isomap", "t-SNE"])

y_true = LabelEncoder().fit_transform(raw_data["GroupBlock"])
n_components = 3
for reduction_model, name in (
    (PCA(n_components=n_components), "PCA"),
    (Isomap(n_components=n_components), "Isomap"),
    (TSNE(n_components=n_components, init="pca", learning_rate="auto", perplexity=30), "t-SNE")
):
    rand_acc, silhouette_coeff = cluster_on_latent_space(X, reduction_model, y_true)
    metrics.loc[name, "rand_acc"] = rand_acc
    metrics.loc[name, "silhouette_coeff"] = silhouette_coeff

metrics
