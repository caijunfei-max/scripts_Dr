# %%
from mp_api.client.mprester import MPRester

# %%
from pymatgen.core.periodic_table import Element

# %%
API_KEY = "fqPPo7Czb5mkbFh8mltlZd0I33csuKv0"
mpr = MPRester(API_KEY)
# Out:
# D:\python\conda\lib\site-packages\mp_api\client\mprester.py:182: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(

# %%
#下载所有含有Li，O的结构
docs=mpr.summary.search(elements=['Li', 'O'], all_fields=True)
# fields=['material_id', 'composition_reduced', 'chemsys','density', 
#                                                                       'structure', 'energy_above_hull', 'band_gap', 
#                                                                       'efermi', 'is_gap_direct', 'theoretical'])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/17066 [00:00<?, ?it/s]
# D:\python\conda\lib\site-packages\mp_api\client\core\client.py:540: UserWarning: Use the 'fields' argument to select only fields of interest to speed up data retrieval for large queries. Choose from: ['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'composition_reduced', 'formula_pretty', 'formula_anonymous', 'chemsys', 'volume', 'density', 'density_atomic', 'symmetry', 'property_name', 'material_id', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'structure', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'energy_above_hull', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'band_gap', 'cbm', 'vbm', 'efermi', 'is_gap_direct', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'theoretical', 'database_IDs']
#   warnings.warn(

# %%
a =docs[0]
a
# Out:
# MPDataDoc<SummaryDoc>(
# composition_reduced=Comp: Li2 Mn3 Cr3 O12,
# chemsys='Cr-Li-Mn-O',
# density=3.907423449069493,
# material_id=MPID(mp-850956),
# structure=Structure Summary
# Lattice
#     abc : 8.803145 5.117054 5.25815480864628
#  angles : 70.90137648237602 90.0 90.0
#  volume : 223.82220294415154
#       A : 8.803145 0.0 0.0
#       B : 0.0 5.117054 0.0
#       C : 0.0 1.720443 4.968729
#     pbc : True True True
# PeriodicSite: Li (4.4016, 0.0000, 0.0000) [0.5000, 0.0000, 0.0000]
# PeriodicSite: Li (0.0000, 2.5585, 0.0000) [0.0000, 0.5000, 0.0000]
# PeriodicSite: Mn (2.9207, 0.8602, 2.4844) [0.3318, 0.0000, 0.5000]
# PeriodicSite: Mn (5.8825, 0.8602, 2.4844) [0.6682, 0.0000, 0.5000]
# PeriodicSite: Mn (0.0000, 0.8602, 2.4844) [0.0000, 0.0000, 0.5000]
# PeriodicSite: Cr (4.4016, 3.4187, 2.4844) [0.5000, 0.5000, 0.5000]
# PeriodicSite: Cr (7.2968, 3.4187, 2.4844) [0.8289, 0.5000, 0.5000]
# PeriodicSite: Cr (1.5063, 3.4187, 2.4844) [0.1711, 0.5000, 0.5000]
# PeriodicSite: O (4.4016, 5.2049, 3.4909) [0.5000, 0.7809, 0.7026]
# PeriodicSite: O (7.3670, 5.1432, 3.4907) [0.8369, 0.7689, 0.7025]
# PeriodicSite: O (1.4362, 5.1432, 3.4907) [0.1631, 0.7689, 0.7025]
# PeriodicSite: O (2.9504, 2.5043, 3.4927) [0.3352, 0.2531, 0.7029]
# PeriodicSite: O (5.8527, 2.5043, 3.4927) [0.6648, 0.2531, 0.7029]
# PeriodicSite: O (0.0000, 2.5796, 3.4413) [0.0000, 0.2712, 0.6926]
# PeriodicSite: O (2.9504, 4.3332, 1.4760) [0.3352, 0.7469, 0.2971]
# PeriodicSite: O (5.8527, 4.3332, 1.4760) [0.6648, 0.7469, 0.2971]
# PeriodicSite: O (0.0000, 4.2579, 1.5274) [0.0000, 0.7288, 0.3074]
# PeriodicSite: O (4.4016, 1.6326, 1.4778) [0.5000, 0.2191, 0.2974]
# PeriodicSite: O (7.3670, 1.6943, 1.4781) [0.8369, 0.2311, 0.2975]
# PeriodicSite: O (1.4362, 1.6943, 1.4781) [0.1631, 0.2311, 0.2975],
# energy_above_hull=0.07494336387500233,
# band_gap=0.0927,
# efermi=1.58868861,
# is_gap_direct=False,
# theoretical=True,
# fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
# )

# %%
ele_list = docs[0].chemsys.split('-')
# a = ["O", "C"]
def if_tm(element_list):
    # 返回体系中是否有过渡金属,输入应尬是一个列表，里面是各个元素的字符串
    for ele in element_list:
        if 'd' in Element(ele).electronic_structure:
            tm = 1
            break
        else:
            tm = 0
    return bool(tm)

def tm_number(composition):
    #返回结构中过渡金属的化学计量，输入应为上面爬的数据中的composition_reduced属性
    #前置库：pymatgen.periodic_table.Element
    tm = []
    ele_dict= composition.as_dict()
    ele = list(ele_dict.keys())
    for i in ele: 
        if 'd' in Element(i).electronic_structure:
            tm.append(i)
    stoihiometry_tm = 0
    for ele in tm:
        stoihiometry_tm += int(ele_dict[ele])
    return stoihiometry_tm

# %%
#选择具有过渡金属且锂原子更多的结构
rich_lithium_docs = []
for i in docs:
    ele_list = i.chemsys.split('-')
    stoichiometry_li = int(i.composition_reduced.as_dict()["Li"])
    stoichiometry_tm = tm_number(i.composition_reduced)
    if if_tm(ele_list)==True and stoichiometry_li > stoichiometry_tm:
        rich_lithium_docs.append(i)

# %%
rich_lithium_docs[:10]
# Out:
# [MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li7 Mn4 Co1 O12,
#  chemsys='Co-Li-Mn-O',
#  density=3.936521933949453,
#  material_id=MPID(mp-1175256),
#  structure=Structure Summary
#  Lattice
#      abc : 2.974031 5.088312604306559 15.041613085759952
#   angles : 96.22129275400442 93.63750082568448 103.5607925488666
#   volume : 219.04110366464872
#        A : 2.974031 0.0 0.0
#        B : -1.193092 4.946459 0.0
#        C : -0.954296 -1.906965 14.889692
#      pbc : True True True
#  PeriodicSite: Li (0.2875, 2.7607, 1.4049) [0.3654, 0.5945, 0.0944]
#  PeriodicSite: Li (1.7665, 3.2069, 3.5605) [0.9678, 0.7405, 0.2391]
#  PeriodicSite: Li (0.5219, 3.7763, 6.2252) [0.6806, 0.9246, 0.4181]
#  PeriodicSite: Li (0.3257, -0.6844, 8.6553) [0.3304, 0.0857, 0.5813]
#  PeriodicSite: Li (-1.0081, -0.1930, 11.1704) [0.0021, 0.2502, 0.7502]
#  PeriodicSite: Li (0.5870, 0.2525, 13.6515) [0.6538, 0.4045, 0.9168]
#  PeriodicSite: Li (1.6248, 0.5120, 2.4994) [0.6677, 0.1682, 0.1679]
#  PeriodicSite: Mn (0.0255, -0.0059, 0.1033) [0.0114, 0.0015, 0.0069]
#  PeriodicSite: Mn (0.2563, 1.0233, 4.8942) [0.3255, 0.3336, 0.3287]
#  PeriodicSite: Mn (0.5448, 2.0184, 9.8910) [0.6628, 0.6641, 0.6643]
#  PeriodicSite: Mn (-0.7671, 2.5597, 12.4117) [0.3461, 0.8388, 0.8336]
#  PeriodicSite: Co (1.8542, 1.4861, 7.4196) [0.9810, 0.4925, 0.4983]
#  PeriodicSite: O (1.5154, 1.1649, 0.5483) [0.6215, 0.2497, 0.0368]
#  PeriodicSite: O (0.2659, 1.8725, 3.2852) [0.3462, 0.4636, 0.2206]
#  PeriodicSite: O (1.7841, 2.1864, 5.6196) [0.9567, 0.5875, 0.3774]
#  PeriodicSite: O (0.5869, 2.7769, 8.0640) [0.6801, 0.7702, 0.5416]
#  PeriodicSite: O (-0.7224, 3.3292, 10.5842) [0.3651, 0.9471, 0.7108]
#  PeriodicSite: O (-0.8719, -1.1173, 13.1034) [0.0347, 0.1134, 0.8800]
#  PeriodicSite: O (1.7904, 4.0932, 1.7125) [0.9887, 0.8718, 0.1150]
#  PeriodicSite: O (1.7388, -0.1515, 4.4508) [0.7145, 0.0846, 0.2989]
#  PeriodicSite: O (0.2029, 0.2624, 6.7760) [0.3059, 0.2285, 0.4551]
#  PeriodicSite: O (1.8322, 0.7272, 9.2045) [0.9690, 0.3853, 0.6182]
#  PeriodicSite: O (0.5001, 1.2430, 11.7244) [0.6434, 0.5548, 0.7874]
#  PeriodicSite: O (-0.6739, 1.8548, 14.2715) [0.3796, 0.7445, 0.9585],
#  energy_above_hull=0.059533691354165086,
#  band_gap=0.7477,
#  efermi=2.61398103,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li7 Mn5 O12,
#  chemsys='Li-Mn-O',
#  density=3.8474342702816564,
#  material_id=MPID(mp-1175344),
#  structure=Structure Summary
#  Lattice
#      abc : 2.990613 5.103186582343331 15.115293247106356
#   angles : 96.21632443931018 93.49681157029084 103.2029396023601
#   volume : 222.3887261621292
#        A : 2.990613 0.0 0.0
#        B : -1.165572 4.968295 0.0
#        C : -0.921927 -1.897447 14.967359
#      pbc : True True True
#  PeriodicSite: Li (-0.9446, -0.1101, 11.2219) [0.0182, 0.2642, 0.7498]
#  PeriodicSite: Li (0.6584, 0.3209, 13.7164) [0.6643, 0.4146, 0.9164]
#  PeriodicSite: Li (0.2447, 2.7499, 1.2510) [0.3357, 0.5854, 0.0836]
#  PeriodicSite: Li (1.8477, 3.1810, 3.7455) [0.9818, 0.7358, 0.2502]
#  PeriodicSite: Li (0.6337, 3.8074, 6.4016) [0.7061, 0.9297, 0.4277]
#  PeriodicSite: Li (0.2694, -0.7366, 8.5658) [0.2939, 0.0703, 0.5723]
#  PeriodicSite: Li (-1.0437, 1.5354, 7.4837) [0.0000, 0.5000, 0.5000]
#  PeriodicSite: Mn (0.5774, 2.0539, 9.8724) [0.6557, 0.6653, 0.6596]
#  PeriodicSite: Mn (0.3258, 1.0169, 5.0950) [0.3443, 0.3347, 0.3404]
#  PeriodicSite: Mn (-0.7781, 2.5231, 12.4493) [0.3180, 0.8255, 0.8318]
#  PeriodicSite: Mn (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#  PeriodicSite: Mn (1.6812, 0.5478, 2.5180) [0.6820, 0.1745, 0.1682]
#  PeriodicSite: O (-0.8785, 3.2256, 10.5941) [0.2828, 0.9195, 0.7078]
#  PeriodicSite: O (-0.8790, -1.1236, 13.1385) [0.0192, 0.1091, 0.8778]
#  PeriodicSite: O (1.7130, 1.3065, 0.6867) [0.6962, 0.2805, 0.0459]
#  PeriodicSite: O (0.3796, 1.8120, 3.2035) [0.3669, 0.4464, 0.2140]
#  PeriodicSite: O (1.8284, 2.1848, 5.5379) [0.9519, 0.5811, 0.3700]
#  PeriodicSite: O (0.5873, 2.9059, 8.2625) [0.6767, 0.7957, 0.5520]
#  PeriodicSite: O (0.5235, 1.2589, 11.7639) [0.6331, 0.5536, 0.7860]
#  PeriodicSite: O (-0.8099, 1.7643, 14.2806) [0.3038, 0.7195, 0.9541]
#  PeriodicSite: O (1.7821, 4.1944, 1.8288) [0.9808, 0.8909, 0.1222]
#  PeriodicSite: O (1.7816, -0.1547, 4.3733) [0.7172, 0.0804, 0.2922]
#  PeriodicSite: O (0.3158, 0.1650, 6.7049) [0.3233, 0.2043, 0.4480]
#  PeriodicSite: O (-0.9252, 0.8860, 9.4295) [0.0481, 0.4189, 0.6300],
#  energy_above_hull=0.04805159687500016,
#  band_gap=0.6739000000000002,
#  efermi=2.66474934,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li9 Mn2 Co5 O16,
#  chemsys='Co-Li-Mn-O',
#  density=4.125581991719113,
#  material_id=MPID(mp-1176207),
#  structure=Structure Summary
#  Lattice
#      abc : 3.015545 7.789891000386591 12.505737279977298
#   angles : 89.49890539727507 89.77268532878743 82.15365427913353
#   volume : 291.0067428671461
#        A : 3.015545 0.0 0.0
#        B : 1.063452 7.71696 0.0
#        C : 0.049615 0.103567 12.50521
#      pbc : True True True
#  PeriodicSite: Li (1.2393, 4.8365, 0.7668) [0.1892, 0.6259, 0.0613]
#  PeriodicSite: Li (2.9783, 0.9529, 3.9534) [0.9404, 0.1192, 0.3161]
#  PeriodicSite: Li (2.7581, 4.8819, 6.9754) [0.6850, 0.6251, 0.5578]
#  PeriodicSite: Li (2.8914, 2.9940, 11.7580) [0.8110, 0.3754, 0.9402]
#  PeriodicSite: Li (2.6338, 6.7647, 2.3819) [0.5620, 0.8740, 0.1905]
#  PeriodicSite: Li (1.3682, 2.9380, 5.5069) [0.3143, 0.3748, 0.4404]
#  PeriodicSite: Li (1.5042, 1.0569, 10.1252) [0.4410, 0.1261, 0.8097]
#  PeriodicSite: Li (1.1424, 6.8593, 8.5585) [0.0574, 0.8797, 0.6844]
#  PeriodicSite: Li (2.5965, 7.7621, 6.2506) [0.5005, 0.9991, 0.4998]
#  PeriodicSite: Mn (4.0617, 7.7077, 0.0055) [0.9947, 0.9988, 0.0004]
#  PeriodicSite: Mn (1.3227, 3.9329, 9.3495) [0.2501, 0.4996, 0.7476]
#  PeriodicSite: Co (2.8060, 3.9055, 3.1540) [0.7491, 0.5027, 0.2522]
#  PeriodicSite: Co (2.7227, 5.8754, 10.9284) [0.6241, 0.7496, 0.8739]
#  PeriodicSite: Co (1.3880, 1.9572, 1.6046) [0.3693, 0.2519, 0.1283]
#  PeriodicSite: Co (1.1901, 5.9126, 4.7394) [0.1200, 0.7611, 0.3790]
#  PeriodicSite: Co (2.9645, 1.8988, 7.7453) [0.8890, 0.2377, 0.6194]
#  PeriodicSite: O (2.7398, 6.2830, 0.2953) [0.6212, 0.8139, 0.0236]
#  PeriodicSite: O (1.3569, 2.4702, 3.4483) [0.3339, 0.3164, 0.2757]
#  PeriodicSite: O (1.1900, 6.2357, 6.4558) [0.1036, 0.8011, 0.5162]
#  PeriodicSite: O (1.4040, 4.4854, 11.2315) [0.2501, 0.5692, 0.8981]
#  PeriodicSite: O (2.9208, 0.5615, 1.8746) [0.9412, 0.0708, 0.1499]
#  PeriodicSite: O (2.8778, 4.4410, 4.9711) [0.7467, 0.5701, 0.3975]
#  PeriodicSite: O (2.9971, 2.4971, 9.6040) [0.8708, 0.3133, 0.7680]
#  PeriodicSite: O (1.5966, 0.6561, 8.1621) [0.4918, 0.0763, 0.6527]
#  PeriodicSite: O (2.8607, 3.3768, 1.3013) [0.7931, 0.4362, 0.1041]
#  PeriodicSite: O (2.5564, 7.1563, 4.3384) [0.5166, 0.9227, 0.3469]
#  PeriodicSite: O (1.2791, 3.3675, 7.5025) [0.2632, 0.4283, 0.6000]
#  PeriodicSite: O (1.3514, 1.5527, 12.2148) [0.3657, 0.1881, 0.9768]
#  PeriodicSite: O (1.2581, 5.3063, 2.9019) [0.1720, 0.6845, 0.2321]
#  PeriodicSite: O (2.9387, 1.5678, 6.0323) [0.8972, 0.1967, 0.4824]
#  PeriodicSite: O (1.0438, 7.2409, 10.6352) [0.0053, 0.9269, 0.8505]
#  PeriodicSite: O (2.6650, 5.3590, 9.0579) [0.6304, 0.6847, 0.7243],
#  energy_above_hull=0.12836463218750005,
#  band_gap=0.0,
#  efermi=2.48963663,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li2 Si3 Ni1 O8,
#  chemsys='Li-Ni-O-Si',
#  density=2.804621420529194,
#  material_id=MPID(mp-863431),
#  structure=Structure Summary
#  Lattice
#      abc : 10.079864 4.935737 6.7795600192685805
#   angles : 89.42279498486783 90.0 90.0
#   volume : 337.2765559831904
#        A : 10.079864 0.0 0.0
#        B : 0.0 4.935737 0.0
#        C : 0.0 0.068297 6.779216
#      pbc : True True True
#  PeriodicSite: Li (8.6008, 0.3970, 5.0883) [0.8533, 0.0700, 0.7506]
#  PeriodicSite: Li (3.5609, 4.6070, 1.6909) [0.3533, 0.9300, 0.2494]
#  PeriodicSite: Li (6.6396, 2.9405, 1.7891) [0.6587, 0.5921, 0.2639]
#  PeriodicSite: Li (1.5997, 2.0636, 4.9901) [0.1587, 0.4079, 0.7361]
#  PeriodicSite: Si (6.6897, 2.8000, 5.2476) [0.6637, 0.5566, 0.7741]
#  PeriodicSite: Si (0.8833, 4.7143, 3.2574) [0.0876, 0.9485, 0.4805]
#  PeriodicSite: Si (5.9233, 0.2898, 3.5218) [0.5876, 0.0515, 0.5195]
#  PeriodicSite: Si (1.6498, 2.2041, 1.5316) [0.1637, 0.4434, 0.2259]
#  PeriodicSite: Si (4.0899, 2.0624, 6.5968) [0.4058, 0.4044, 0.9731]
#  PeriodicSite: Si (9.1299, 2.9416, 0.1824) [0.9058, 0.5956, 0.0269]
#  PeriodicSite: Ni (8.4547, 0.4085, 1.7067) [0.8388, 0.0793, 0.2518]
#  PeriodicSite: Ni (3.4148, 4.5955, 5.0725) [0.3388, 0.9207, 0.7482]
#  PeriodicSite: O (1.5896, 0.1416, 4.6543) [0.1577, 0.0192, 0.6865]
#  PeriodicSite: O (6.6605, 4.3800, 4.7939) [0.6608, 0.8776, 0.7072]
#  PeriodicSite: O (1.2195, 3.1173, 2.8340) [0.1210, 0.6258, 0.4180]
#  PeriodicSite: O (4.3561, 4.9077, 3.4029) [0.4322, 0.9874, 0.5020]
#  PeriodicSite: O (6.2595, 1.8867, 3.9452) [0.6210, 0.3742, 0.5820]
#  PeriodicSite: O (9.3960, 0.0963, 3.3763) [0.9322, 0.0126, 0.4980]
#  PeriodicSite: O (1.6206, 0.6241, 1.9853) [0.1608, 0.1224, 0.2928]
#  PeriodicSite: O (6.6295, 4.8624, 2.1250) [0.6577, 0.9808, 0.3135]
#  PeriodicSite: O (3.2157, 2.6293, 1.1446) [0.3190, 0.5304, 0.1688]
#  PeriodicSite: O (8.4169, 2.3710, 1.5113) [0.8350, 0.4773, 0.2229]
#  PeriodicSite: O (0.6663, 2.4120, 0.1923) [0.0661, 0.4883, 0.0284]
#  PeriodicSite: O (4.0364, 0.4682, 6.7750) [0.4004, 0.0810, 0.9994]
#  PeriodicSite: O (5.7062, 2.5920, 6.5869) [0.5661, 0.5117, 0.9716]
#  PeriodicSite: O (9.0764, 4.5359, 0.0042) [0.9004, 0.9190, 0.0006]
#  PeriodicSite: O (3.3770, 2.6331, 5.2679) [0.3350, 0.5227, 0.7771]
#  PeriodicSite: O (8.2556, 2.3747, 5.6346) [0.8190, 0.4696, 0.8312],
#  energy_above_hull=0.09311123553571043,
#  band_gap=3.4899000000000004,
#  efermi=1.86189273,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li2 V1 Si1 O5,
#  chemsys='Li-O-Si-V',
#  density=3.0637542826084045,
#  material_id=MPID(mp-18860),
#  structure=Structure Summary
#  Lattice
#      abc : 4.540332000523751 9.086703975984417 9.08596858584477
#   angles : 89.99998216132488 90.00168377868042 90.00046530474752
#   volume : 374.8566515002569
#        A : 3.4e-05 -6e-05 4.540332
#        B : 6.425269 6.425271 -3.7e-05
#        C : -6.424749 6.424751 -0.000134
#      pbc : True True True
#  PeriodicSite: Li (-0.0001, 0.0001, 2.2700) [0.5000, 0.0000, 0.0000]
#  PeriodicSite: Li (0.0002, 6.4248, 2.2701) [0.5000, 0.5000, 0.5000]
#  PeriodicSite: Li (3.2125, 3.2127, 2.2701) [0.5000, 0.5000, 0.0000]
#  PeriodicSite: Li (3.2129, 9.6375, 2.2701) [0.5000, 1.0000, 0.5000]
#  PeriodicSite: Li (-3.2127, 6.4253, 2.2698) [0.4999, 0.2500, 0.7501]
#  PeriodicSite: Li (3.2131, 6.4247, 2.2704) [0.5001, 0.7500, 0.2499]
#  PeriodicSite: Li (0.0005, 3.2121, 2.2697) [0.4999, 0.2500, 0.2499]
#  PeriodicSite: Li (-0.0001, 9.6378, 2.2703) [0.5001, 0.7500, 0.7501]
#  PeriodicSite: V (1.6058, 8.0322, 0.3798) [0.0837, 0.7500, 0.5001]
#  PeriodicSite: V (-1.6058, 4.8182, 4.1617) [0.9166, 0.2500, 0.4999]
#  PeriodicSite: V (-4.8180, 8.0308, 0.3776) [0.0832, 0.2500, 0.9999]
#  PeriodicSite: V (4.8188, 4.8191, 4.1618) [0.9166, 0.7500, 0.0000]
#  PeriodicSite: Si (-1.6058, 8.0310, 4.5399) [0.9999, 0.5000, 0.7500]
#  PeriodicSite: Si (4.8190, 8.0315, 0.0001) [0.0000, 1.0000, 0.2500]
#  PeriodicSite: Si (1.6064, 4.8190, 0.0001) [0.0000, 0.5000, 0.2500]
#  PeriodicSite: Si (-4.8184, 4.8184, 4.5400) [0.9999, 0.0000, 0.7500]
#  PeriodicSite: O (-4.8181, 8.0310, 3.2364) [0.7128, 0.2500, 1.0000]
#  PeriodicSite: O (1.6062, 8.0317, 3.2386) [0.7133, 0.7500, 0.5001]
#  PeriodicSite: O (-1.6053, 11.2433, 1.3033) [0.2871, 0.7500, 0.9999]
#  PeriodicSite: O (-1.6060, 4.8186, 1.3024) [0.2869, 0.2500, 0.5000]
#  PeriodicSite: O (1.6065, 6.1394, 0.9841) [0.2168, 0.6028, 0.3528]
#  PeriodicSite: O (-4.8181, 6.1391, 0.9833) [0.2166, 0.1028, 0.8527]
#  PeriodicSite: O (1.6063, 3.4979, 0.9833) [0.2166, 0.3972, 0.1472]
#  PeriodicSite: O (1.6065, 9.9240, 0.9844) [0.2168, 0.8973, 0.6473]
#  PeriodicSite: O (0.2862, 4.8186, 3.5560) [0.7832, 0.3972, 0.3527]
#  PeriodicSite: O (0.2860, 11.2434, 3.5564) [0.7833, 0.8972, 0.8528]
#  PeriodicSite: O (2.9272, 4.8190, 3.5567) [0.7834, 0.6028, 0.1472]
#  PeriodicSite: O (-3.4980, 4.8186, 3.5560) [0.7832, 0.1028, 0.6472]
#  PeriodicSite: O (-1.6061, 6.7105, 3.5561) [0.7832, 0.3972, 0.6472]
#  PeriodicSite: O (4.8189, 6.7107, 3.5567) [0.7834, 0.8972, 0.1472]
#  PeriodicSite: O (-1.6055, 9.3518, 3.5564) [0.7833, 0.6028, 0.8527]
#  PeriodicSite: O (-1.6061, 2.9263, 3.5559) [0.7832, 0.1027, 0.3527]
#  PeriodicSite: O (-0.2860, 8.0314, 0.9845) [0.2168, 0.6027, 0.6473]
#  PeriodicSite: O (-0.2852, 1.6064, 0.9833) [0.2166, 0.1028, 0.1472]
#  PeriodicSite: O (-2.9264, 8.0308, 0.9833) [0.2166, 0.3972, 0.8527]
#  PeriodicSite: O (3.4985, 8.0314, 0.9841) [0.2168, 0.8972, 0.3528],
#  energy_above_hull=0.0,
#  band_gap=2.3621,
#  efermi=2.45856119,
#  is_gap_direct=False,
#  theoretical=False,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li3 Bi1 P2 O8,
#  chemsys='Bi-Li-O-P',
#  density=4.216147550759737,
#  material_id=MPID(mp-760650),
#  structure=Structure Summary
#  Lattice
#      abc : 5.204259071826171 5.204259071826171 15.144213909062232
#   angles : 83.441380976245 83.441380976245 54.372595447043814
#   volume : 330.6358843301534
#        A : 2.377749 4.629322 0.0
#        B : -2.377749 4.629322 0.0
#        C : 0.0 1.944595 15.018847
#      pbc : True True True
#  PeriodicSite: Li (0.1423, 3.3473, 2.6985) [0.3537, 0.2939, 0.1797]
#  PeriodicSite: Li (-0.1423, 4.3196, 10.2079) [0.2939, 0.3537, 0.6797]
#  PeriodicSite: Li (0.1423, 6.8837, 4.8109) [0.7061, 0.6463, 0.3203]
#  PeriodicSite: Li (-0.1423, 7.8560, 12.3204) [0.6463, 0.7061, 0.8203]
#  PeriodicSite: Li (-2.1440, 5.1155, 3.7547) [0.0492, 0.9508, 0.2500]
#  PeriodicSite: Li (2.1440, 6.0878, 11.2641) [0.9508, 0.0492, 0.7500]
#  PeriodicSite: Bi (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#  PeriodicSite: Bi (0.0000, 0.9723, 7.5094) [0.0000, 0.0000, 0.5000]
#  PeriodicSite: P (0.1535, 3.9111, 5.6177) [0.3762, 0.3116, 0.3740]
#  PeriodicSite: P (-0.1535, 4.8834, 13.1271) [0.3116, 0.3762, 0.8740]
#  PeriodicSite: P (0.1535, 6.3198, 1.8917) [0.6884, 0.6238, 0.1260]
#  PeriodicSite: P (-0.1535, 7.2921, 9.4012) [0.6238, 0.6884, 0.6260]
#  PeriodicSite: O (1.2212, 5.0300, 5.2915) [0.7261, 0.2125, 0.3523]
#  PeriodicSite: O (-1.2212, 6.0023, 12.8009) [0.2125, 0.7261, 0.8523]
#  PeriodicSite: O (-0.5706, 4.3491, 6.8976) [0.2533, 0.4933, 0.4593]
#  PeriodicSite: O (0.5706, 5.3214, 14.4070) [0.4933, 0.2533, 0.9593]
#  PeriodicSite: O (-0.8224, 3.7048, 4.4280) [0.1653, 0.5112, 0.2948]
#  PeriodicSite: O (0.9006, 7.6646, 1.6102) [0.9947, 0.6159, 0.1072]
#  PeriodicSite: O (0.8224, 4.6771, 11.9374) [0.5112, 0.1653, 0.7948]
#  PeriodicSite: O (-0.9006, 8.6369, 9.1196) [0.6159, 0.9947, 0.6072]
#  PeriodicSite: O (0.9006, 2.5663, 5.8992) [0.3841, 0.0053, 0.3928]
#  PeriodicSite: O (-0.8224, 6.5261, 3.0814) [0.4888, 0.8347, 0.2052]
#  PeriodicSite: O (-0.9006, 3.5386, 13.4086) [0.0053, 0.3841, 0.8928]
#  PeriodicSite: O (0.8224, 7.4984, 10.5909) [0.8347, 0.4888, 0.7052]
#  PeriodicSite: O (-0.5706, 5.8818, 0.6118) [0.5067, 0.7467, 0.0407]
#  PeriodicSite: O (0.5706, 6.8541, 8.1212) [0.7467, 0.5067, 0.5407]
#  PeriodicSite: O (1.2212, 5.2009, 2.2179) [0.7875, 0.2739, 0.1477]
#  PeriodicSite: O (-1.2212, 6.1732, 9.7273) [0.2739, 0.7875, 0.6477],
#  energy_above_hull=0.06068815749999956,
#  band_gap=3.1798,
#  efermi=2.05132674,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li9 Mn2 Co5 O16,
#  chemsys='Co-Li-Mn-O',
#  density=4.19949212522354,
#  material_id=MPID(mp-1175757),
#  structure=Structure Summary
#  Lattice
#      abc : 7.71427688943818 7.71427688943818 5.175777618084939
#   angles : 76.24852229018981 76.24852229018981 96.48083551887657
#   volume : 285.88508849212946
#        A : 5.754434 5.137758 0.0
#        B : -5.754434 5.137758 0.0
#        C : 0.0 1.847338 4.834875
#      pbc : True True True
#  PeriodicSite: Li (1.4272, 8.6390, 2.4241) [0.8746, 0.6266, 0.5014]
#  PeriodicSite: Li (5.7514, 6.0614, 2.4174) [0.9997, 0.0003, 0.5000]
#  PeriodicSite: Li (-1.4128, 3.4308, 2.4583) [0.1197, 0.3652, 0.5085]
#  PeriodicSite: Li (-2.9020, 6.0614, 2.4174) [0.2478, 0.7522, 0.5000]
#  PeriodicSite: Li (1.4272, 3.4838, 2.4108) [0.3734, 0.1254, 0.4986]
#  PeriodicSite: Li (-0.0021, 6.0614, 2.4174) [0.4998, 0.5002, 0.5000]
#  PeriodicSite: Li (-1.4128, 8.6920, 2.3766) [0.6348, 0.8803, 0.4915]
#  PeriodicSite: Li (2.9134, 6.0614, 2.4174) [0.7531, 0.2469, 0.5000]
#  PeriodicSite: Li (4.3318, 5.1378, 0.0000) [0.8764, 0.1236, 0.0000]
#  PeriodicSite: Mn (2.8591, 9.5215, 4.8053) [0.9964, 0.4995, 0.9939]
#  PeriodicSite: Mn (2.8591, 2.6014, 0.0296) [0.5005, 0.0036, 0.0061]
#  PeriodicSite: Co (-4.3267, 5.1378, 0.0000) [0.1241, 0.8759, 0.0000]
#  PeriodicSite: Co (-0.0193, 4.3317, 4.8251) [0.2405, 0.2438, 0.9980]
#  PeriodicSite: Co (-1.4189, 5.1378, 0.0000) [0.3767, 0.6233, 0.0000]
#  PeriodicSite: Co (1.4275, 5.1378, 0.0000) [0.6240, 0.3760, 0.0000]
#  PeriodicSite: Co (-0.0193, 7.7912, 0.0097) [0.7562, 0.7595, 0.0020]
#  PeriodicSite: O (1.4728, 6.9586, 1.1161) [0.7637, 0.5077, 0.2308]
#  PeriodicSite: O (0.1052, 9.4370, 1.0843) [0.8872, 0.8689, 0.2243]
#  PeriodicSite: O (-1.4705, 1.8746, 1.1248) [0.0128, 0.2684, 0.2326]
#  PeriodicSite: O (-2.8909, 4.2325, 1.0011) [0.1235, 0.6259, 0.2071]
#  PeriodicSite: O (1.4917, 1.8045, 1.1520) [0.2624, 0.0032, 0.2383]
#  PeriodicSite: O (0.0093, 4.3443, 1.0844) [0.3833, 0.3817, 0.2243]
#  PeriodicSite: O (-1.5041, 6.9305, 1.1418) [0.5013, 0.7627, 0.2362]
#  PeriodicSite: O (2.7996, 4.2359, 1.0401) [0.6168, 0.1303, 0.2151]
#  PeriodicSite: O (1.4917, 10.3183, 3.6828) [0.9968, 0.7376, 0.7617]
#  PeriodicSite: O (0.1052, 2.6859, 3.7506) [0.1311, 0.1128, 0.7757]
#  PeriodicSite: O (-1.5041, 5.1923, 3.6930) [0.2373, 0.4987, 0.7638]
#  PeriodicSite: O (-2.8909, 7.8904, 3.8338) [0.3741, 0.8765, 0.7929]
#  PeriodicSite: O (1.4728, 5.1643, 3.7188) [0.4923, 0.2363, 0.7692]
#  PeriodicSite: O (0.0093, 7.7785, 3.7505) [0.6183, 0.6167, 0.7757]
#  PeriodicSite: O (-1.4705, 10.2482, 3.7101) [0.7316, 0.9872, 0.7674]
#  PeriodicSite: O (2.7996, 7.8870, 3.7948) [0.8697, 0.3832, 0.7849],
#  energy_above_hull=0.07108757875000027,
#  band_gap=0.8129999999999997,
#  efermi=2.41621231,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li3 P3 W2 O12,
#  chemsys='Li-O-P-W',
#  density=4.385319827788272,
#  material_id=MPID(mp-777465),
#  structure=Structure Summary
#  Lattice
#      abc : 9.268275988724763 9.268275988724763 9.268275704191153
#   angles : 55.939295574791025 55.939295574791025 55.93929168883139
#   volume : 509.990342019324
#        A : 8.185706 -4.346856 0.0
#        B : 8.185706 4.346856 0.0
#        C : 5.877394 0.0 7.166392
#      pbc : True True True
#  PeriodicSite: Li (8.6365, 2.8697, 2.4298) [0.0757, 0.7359, 0.3391]
#  PeriodicSite: Li (7.7205, -1.1446, 5.2738) [0.3391, 0.0757, 0.7359]
#  PeriodicSite: Li (9.2444, -1.7251, 0.5427) [0.7359, 0.3391, 0.0757]
#  PeriodicSite: Li (13.0044, 1.7251, 6.6237) [0.2641, 0.6609, 0.9243]
#  PeriodicSite: Li (14.5283, 1.1446, 1.8926) [0.6609, 0.9243, 0.2641]
#  PeriodicSite: Li (13.6123, -2.8697, 4.7366) [0.9243, 0.2641, 0.6609]
#  PeriodicSite: P (8.4836, 1.7963, 5.3728) [0.0424, 0.4557, 0.7497]
#  PeriodicSite: P (10.1163, 1.2782, 0.3040) [0.4557, 0.7497, 0.0424]
#  PeriodicSite: P (9.1624, -3.0745, 3.2655) [0.7497, 0.0424, 0.4557]
#  PeriodicSite: P (13.0864, 3.0745, 3.9009) [0.2503, 0.9576, 0.5443]
#  PeriodicSite: P (12.1325, -1.2782, 6.8624) [0.5443, 0.2503, 0.9576]
#  PeriodicSite: P (13.7652, -1.7963, 1.7936) [0.9576, 0.5443, 0.2503]
#  PeriodicSite: W (7.7132, 0.0000, 2.4844) [0.3467, 0.3467, 0.3467]
#  PeriodicSite: W (14.5356, 0.0000, 4.6820) [0.6533, 0.6533, 0.6533]
#  PeriodicSite: W (3.2098, 0.0000, 1.0339) [0.1443, 0.1443, 0.1443]
#  PeriodicSite: W (19.0390, 0.0000, 6.1325) [0.8557, 0.8557, 0.8557]
#  PeriodicSite: O (6.9169, 1.7545, 1.4613) [0.1475, 0.5511, 0.2039]
#  PeriodicSite: O (6.1154, -0.2453, 3.9494) [0.2039, 0.1475, 0.5511]
#  PeriodicSite: O (7.0471, -1.5092, 1.0569) [0.5511, 0.2039, 0.1475]
#  PeriodicSite: O (8.5089, 1.4880, 3.8458) [0.1559, 0.4982, 0.5366]
#  PeriodicSite: O (8.3465, 0.4736, 6.1801) [0.1458, 0.2547, 0.8624]
#  PeriodicSite: O (9.7024, 2.5831, 5.7838) [0.0058, 0.6000, 0.8071]
#  PeriodicSite: O (10.0007, 2.6414, 1.0445) [0.2547, 0.8624, 0.1458]
#  PeriodicSite: O (9.3877, 0.1669, 1.1174) [0.4982, 0.5366, 0.1559]
#  PeriodicSite: O (8.5975, -1.6550, 3.5706) [0.5366, 0.1559, 0.4982]
#  PeriodicSite: O (12.0685, 3.4831, 2.8664) [0.1929, 0.9942, 0.4000]
#  PeriodicSite: O (12.4996, 3.1150, 5.3410) [0.1376, 0.8542, 0.7453]
#  PeriodicSite: O (10.6968, -0.9000, 7.1250) [0.4000, 0.1929, 0.9942]
#  PeriodicSite: O (11.5520, 0.9000, 0.0414) [0.6000, 0.8071, 0.0058]
#  PeriodicSite: O (9.7492, -3.1150, 1.8254) [0.8624, 0.1458, 0.2547]
#  PeriodicSite: O (10.1803, -3.4831, 4.3000) [0.8071, 0.0058, 0.6000]
#  PeriodicSite: O (13.6513, 1.6550, 3.5958) [0.4634, 0.8441, 0.5018]
#  PeriodicSite: O (12.8611, -0.1669, 6.0490) [0.5018, 0.4634, 0.8441]
#  PeriodicSite: O (12.2481, -2.6414, 6.1219) [0.7453, 0.1376, 0.8542]
#  PeriodicSite: O (12.5464, -2.5831, 1.3826) [0.9942, 0.4000, 0.1929]
#  PeriodicSite: O (13.9023, -0.4736, 0.9863) [0.8542, 0.7453, 0.1376]
#  PeriodicSite: O (13.7399, -1.4880, 3.3206) [0.8441, 0.5018, 0.4634]
#  PeriodicSite: O (15.2017, 1.5092, 6.1095) [0.4489, 0.7961, 0.8525]
#  PeriodicSite: O (16.1334, 0.2453, 3.2169) [0.7961, 0.8525, 0.4489]
#  PeriodicSite: O (15.3319, -1.7545, 5.7051) [0.8525, 0.4489, 0.7961],
#  energy_above_hull=0.036370962874996415,
#  band_gap=3.6739,
#  efermi=2.03588326,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li2 Co1 P2 O7,
#  chemsys='Co-Li-O-P',
#  density=3.067370774222684,
#  material_id=MPID(mp-697726),
#  structure=Structure Summary
#  Lattice
#      abc : 5.060204 7.003856024492865 8.200799881706295
#   angles : 113.11351159513138 91.14366500973274 90.9347328468029
#   volume : 267.1683281716704
#        A : 5.060204 0.0 0.0
#        B : -0.114257 7.002924 0.0
#        C : -0.163683 -3.222356 7.539413
#      pbc : True True True
#  PeriodicSite: Li (1.0380, 4.3086, 3.2384) [0.2374, 0.8129, 0.4295]
#  PeriodicSite: Li (3.4032, -2.1410, 7.5038) [0.7082, 0.1522, 0.9953]
#  PeriodicSite: Li (1.3791, 5.9216, 0.0356) [0.2918, 0.8478, 0.0047]
#  PeriodicSite: Li (3.7443, -0.5280, 4.3010) [0.7626, 0.1871, 0.5705]
#  PeriodicSite: Co (3.7435, 3.0064, 5.4409) [0.7803, 0.7614, 0.7217]
#  PeriodicSite: Co (1.0388, 0.7742, 2.0985) [0.2197, 0.2386, 0.2783]
#  PeriodicSite: P (1.2856, 0.9446, 5.2400) [0.2868, 0.4547, 0.6950]
#  PeriodicSite: P (0.9991, -1.7932, 6.1986) [0.2268, 0.1222, 0.8222]
#  PeriodicSite: P (3.7831, 5.5738, 1.3408) [0.7732, 0.8778, 0.1778]
#  PeriodicSite: P (3.4967, 2.8360, 2.2994) [0.7132, 0.5453, 0.3050]
#  PeriodicSite: O (4.2469, 1.6738, 1.6472) [0.8540, 0.3395, 0.2185]
#  PeriodicSite: O (0.5542, 0.3427, 4.0304) [0.1335, 0.2949, 0.5346]
#  PeriodicSite: O (0.2280, 5.7419, 1.6419) [0.0729, 0.9201, 0.2178]
#  PeriodicSite: O (4.2281, 3.4379, 3.5090) [0.8665, 0.7051, 0.4654]
#  PeriodicSite: O (4.5543, -1.9613, 5.8976) [0.9271, 0.0799, 0.7822]
#  PeriodicSite: O (2.7762, 1.2163, 5.0010) [0.5809, 0.4789, 0.6633]
#  PeriodicSite: O (1.7985, 4.6677, 5.1009) [0.3994, 0.9779, 0.6766]
#  PeriodicSite: O (3.5160, 3.9915, 1.1501) [0.7142, 0.6402, 0.1525]
#  PeriodicSite: O (2.0061, 2.5643, 2.5384) [0.4191, 0.5211, 0.3367]
#  PeriodicSite: O (3.2335, 2.8891, 7.4881) [0.6908, 0.8696, 0.9932]
#  PeriodicSite: O (2.9838, -0.8871, 2.4385) [0.6006, 0.0221, 0.3234]
#  PeriodicSite: O (1.5488, 0.8914, 0.0513) [0.3092, 0.1304, 0.0068]
#  PeriodicSite: O (0.5354, 2.1068, 5.8922) [0.1460, 0.6605, 0.7815]
#  PeriodicSite: O (1.2662, -0.2110, 6.3893) [0.2858, 0.3598, 0.8475],
#  energy_above_hull=0.03415897201386908,
#  band_gap=3.0107999999999997,
#  efermi=1.68814826,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  ),
#  MPDataDoc<SummaryDoc>(
#  composition_reduced=Comp: Li3 Mn1 Si1 C1 O7,
#  chemsys='C-Li-Mn-O-Si',
#  density=2.7732029819238817,
#  material_id=MPID(mp-772668),
#  structure=Structure Summary
#  Lattice
#      abc : 5.064045570392905 8.545316101573421 6.3169660000285734
#   angles : 90.00033986811805 90.00000483269088 86.56267935777326
#   volume : 272.8677887139621
#        A : 0.14201 0.0 5.062054
#        B : 8.540956 -2.5e-05 0.272943
#        C : -1.9e-05 6.316966 0.0
#      pbc : True True True
#  PeriodicSite: Li (1.0979, 1.5792, 3.8624) [0.7568, 0.1160, 0.2500]
#  PeriodicSite: Li (7.5855, 4.7377, 1.4737) [0.2435, 0.8841, 0.7500]
#  PeriodicSite: Li (2.4512, 0.2126, 1.3072) [0.2430, 0.2830, 0.0337]
#  PeriodicSite: Li (2.4512, 2.9458, 1.3072) [0.2430, 0.2830, 0.4663]
#  PeriodicSite: Li (6.2321, 3.3712, 4.0278) [0.7570, 0.7171, 0.5337]
#  PeriodicSite: Li (6.2321, 6.1042, 4.0278) [0.7570, 0.7171, 0.9663]
#  PeriodicSite: Mn (5.7443, 1.5795, 1.1673) [0.1945, 0.6693, 0.2500]
#  PeriodicSite: Mn (2.9391, 4.7375, 4.1662) [0.8052, 0.3307, 0.7500]
#  PeriodicSite: Si (3.7313, 1.5792, 3.7262) [0.7132, 0.4250, 0.2500]
#  PeriodicSite: Si (4.9516, 4.7377, 1.6081) [0.2867, 0.5750, 0.7500]
#  PeriodicSite: C (0.3430, 4.7377, 3.7038) [0.7302, 0.0280, 0.7500]
#  PeriodicSite: C (8.3396, 1.5792, 1.6321) [0.2700, 0.9719, 0.2500]
#  PeriodicSite: O (0.9967, 1.5792, 1.8577) [0.3610, 0.1107, 0.2500]
#  PeriodicSite: O (7.6858, 4.7377, 3.4790) [0.6393, 0.8892, 0.7500]
#  PeriodicSite: O (0.5840, 4.7377, 4.9634) [0.9777, 0.0521, 0.7500]
#  PeriodicSite: O (8.0995, 1.5792, 0.3724) [0.0224, 0.9479, 0.2500]
#  PeriodicSite: O (1.3699, 4.7377, 2.8735) [0.5595, 0.1511, 0.7500]
#  PeriodicSite: O (7.3121, 1.5792, 2.4615) [0.4405, 0.8488, 0.2500]
#  PeriodicSite: O (3.8243, 1.5792, 2.0887) [0.3888, 0.4413, 0.2500]
#  PeriodicSite: O (4.8584, 4.7377, 3.2456) [0.6110, 0.5587, 0.7500]
#  PeriodicSite: O (3.4335, 4.7377, 0.9960) [0.1752, 0.3991, 0.7500]
#  PeriodicSite: O (5.2492, 1.5792, 4.3385) [0.8247, 0.6009, 0.2500]
#  PeriodicSite: O (2.7801, 0.3367, 4.2754) [0.8278, 0.3117, 0.0533]
#  PeriodicSite: O (2.7801, 2.8217, 4.2754) [0.8278, 0.3117, 0.4467]
#  PeriodicSite: O (5.9028, 3.4953, 1.0591) [0.1721, 0.6883, 0.5533]
#  PeriodicSite: O (5.9028, 5.9801, 1.0591) [0.1721, 0.6883, 0.9467],
#  energy_above_hull=0.04134151003925535,
#  band_gap=0.8431000000000002,
#  efermi=1.71284333,
#  is_gap_direct=False,
#  theoretical=True,
#  fields_not_requested=['builder_meta', 'nsites', 'elements', 'nelements', 'composition', 'formula_pretty', 'formula_anonymous', 'volume', 'density_atomic', 'symmetry', 'property_name', 'deprecated', 'deprecation_reasons', 'last_updated', 'origins', 'warnings', 'task_ids', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'is_stable', 'equilibrium_reaction_energy_per_atom', 'decomposes_to', 'xas', 'grain_boundaries', 'cbm', 'vbm', 'is_metal', 'es_source_calc_id', 'bandstructure', 'dos', 'dos_energy_up', 'dos_energy_down', 'is_magnetic', 'ordering', 'total_magnetization', 'total_magnetization_normalized_vol', 'total_magnetization_normalized_formula_units', 'num_magnetic_sites', 'num_unique_magnetic_sites', 'types_of_magnetic_species', 'k_voigt', 'k_reuss', 'k_vrh', 'g_voigt', 'g_reuss', 'g_vrh', 'universal_anisotropy', 'homogeneous_poisson', 'e_total', 'e_ionic', 'e_electronic', 'n', 'e_ij_max', 'weighted_surface_energy_EV_PER_ANG2', 'weighted_surface_energy', 'weighted_work_function', 'surface_anisotropy', 'shape_factor', 'has_reconstructed', 'possible_species', 'has_props', 'database_IDs']
#  )]
